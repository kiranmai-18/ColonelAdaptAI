# %% [markdown]
# # ColonelAdaptAI Quick Colab Run
# Upload the ZIP, unzip it, install requirements, and run Split MNIST.

# %%
# !unzip -q ColonelAdaptAI.zip
# %cd ColonelAdaptAI
# !pip install -q -r requirements.txt
# !python main.py --dataset split_mnist --epochs 2 --batch-size 128 --output-dir results/demo
